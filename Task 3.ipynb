# %% [markdown]
# # <font color='red'>GRIP internship</font>

# %% [markdown]
# # <font color='#33CC99'>Task 03 : Exploratory Data Analysis - Retail</font>

# %% [markdown]
# # By : Pankaj Kumar Barman

# %% [markdown]
# # Target :
#                   ● As a business manager, try to find out the weak areas where you can work to
#                     make more profit.
#                   ● What all business problems you can derive by exploring the data?

# %%
# importing the libraries
import numpy as np
import pandas as pd
pd.set_option("display.max_columns", 100)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings("ignore")

# %%
# import data set
data = pd.read_csv("SampleSuperstore.csv")

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
data.shape
# Out:
# (9994, 13)

# %% [markdown]
# # Exploreratory Data AnaLysis - Retail

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data["Ship Mode"].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
data['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
data['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
data["City"].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
data['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
data['Postal Code'].unique()
# Out:
# array([42420, 90036, 33311, 90032, 28027, 98103, 76106, 53711, 84084,
#        94109, 68025, 19140, 84057, 90049, 77095, 75080, 77041, 60540,
#        32935, 55122, 48185, 19901, 47150, 10024, 12180, 90004, 60610,
#        85234, 22153, 10009, 49201, 38109, 77070, 35601, 94122, 27707,
#        60623, 29203, 55901, 55407, 97206, 55106, 80013, 28205, 60462,
#        10035, 50322, 43229, 37620, 19805, 61701, 85023, 95661, 64055,
#        91104, 43055, 53132, 85254, 95123, 98105, 98115, 73034, 90045,
#        19134, 88220, 78207, 77036, 62521, 71203,  6824, 75051, 92374,
#        45011,  7090, 19120, 44312, 80219, 75220, 37064, 90604, 48601,
#        44256, 43017, 48227, 38401, 33614, 95051, 55044, 92037, 77506,
#        94513, 27514,  7960, 45231, 94110, 90301, 33319, 80906,  7109,
#        48180,  8701, 22204, 80004,  7601, 33710, 19143, 90805, 92345,
#        37130, 84041, 78745,  1852, 31907,  6040, 78550, 85705, 62301,
# ...

# %%
data['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
data['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
data['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
data['Sales'].unique()
# Out:
# array([261.96 , 731.94 ,  14.62 , ..., 437.472,  97.98 , 243.16 ])

# %%
data['Quantity'].unique()
# Out:
# array([ 2,  3,  5,  7,  4,  6,  9,  1,  8, 14, 11, 13, 10, 12],
#       dtype=int64)

# %%
data['Discount'].unique()
# Out:
# array([0.  , 0.45, 0.2 , 0.8 , 0.3 , 0.5 , 0.7 , 0.6 , 0.32, 0.1 , 0.4 ,
#        0.15])

# %%
data['Profit'].unique()
# Out:
# array([ 41.9136, 219.582 ,   6.8714, ...,  16.124 ,   4.1028,  72.948 ])

# %%
list1 = data.columns

# %%
list1
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df = data.copy()

# %% [markdown]
# ### understand DATA CHARACTERISTICS

# %%
# ---- DATA CHARACTERISTICS  ------------------------#
# Data Characteristics
def data_characteristics(dataset):
    # shape of the dataset
    print("Shape of the Dataset : {}".format(dataset.shape))
    print("Number of Columns in the Dataset : {}".format(dataset.shape[1]))
    print("Number of Rows in the Dataset : {}".format(dataset.shape[0]))
    print("-"*30)
    
    # Understanding the Number of Numeric and Categorical features in dataset
    numeric_features = dataset.select_dtypes(include = [np.number])
    categoric_features = dataset.select_dtypes(exclude = [np.number])
    print("Number of Numerical Features : {}".format(numeric_features.shape[1]))
    print("Number of Categorical Features : {}".format(categoric_features.shape[1]))
    print("-"*30)
    
    # Unique values
    print("No of unique values : {}".format(dataset.nunique()))
    print("-"*30)
    
    # Number of NOT NUll Values
    print("No of NON-NANS : {}".format(dataset.count()))
    print("-"*30)
    
    # Understanding the dataset
    print("Information of the Dataset : {}".format(dataset.info(verbose = False, memory_usage = "deep")))
    print("-"*30)
    
#------------------------------------------------------------------------------#

# dataset Characteristics
print(data_characteristics(df))
# Out:
# Shape of the Dataset : (9994, 13)
# Number of Columns in the Dataset : 13
# Number of Rows in the Dataset : 9994
# ------------------------------
# Number of Numerical Features : 5
# Number of Categorical Features : 8
# ------------------------------
# No of unique values : Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64
# ------------------------------
# No of NON-NANS : Ship Mode       9994
# Segment         9994
# Country         9994
# City            9994
# State           9994
# Postal Code     9994
# Region          9994
# Category        9994
# Sub-Category    9994
# Sales           9994
# Quantity        9994
# Discount        9994
# Profit          9994
# dtype: int64
# ------------------------------
# ...

# %%
df.isnull().sum()  ## nulvalue not present
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
## for null values
plt.figure(figsize=(8,8))
sns.heatmap(df.isnull())

# %%
sns.pairplot(df)

# %% [markdown]
# # check for outlires

# %%
sns.boxplot(x = df["Postal Code"])

# %%
sns.boxplot(x = df["Sales"])

# %%
sns.boxplot(x = df["Quantity"])

# %%
sns.boxplot(x = df["Discount"])

# %%
sns.boxplot(x = df["Profit"])

# %%
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %% [markdown]
# # checking for duplicate values

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates(subset = None, keep = 'first', inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # plot corelation matrixs

# %%
corr = df.corr()
sns.heatmap(corr, annot = True)
plt.show()

# %%
# Let's try to visualize the 'Segment' column from the dataset.

sns.set_style('whitegrid')
sns.countplot(x='Segment',data=df, palette='rainbow')

# %%
df["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
# Let's try to visualize the 'Category' column from the dataset.

sns.set_style('whitegrid')
sns.countplot(x='Category',data=df, palette='rainbow')

# %%
plt.figure(figsize=(12,10))
df['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
#Let's try to visualize the 'state' column from the dataset.
plt.figure(figsize=(20,10))
sns.set_style('whitegrid')
sns.countplot(x='State',data=df, palette='rainbow',order = df['State'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [raw]
# # here from above diagram we can clearly see that compay earns most profit from California and Least profit from North
# Dakota and company have no profit from West Virginia and Wyoming so we need to look on that and make sure to earn profit
# from this states

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
# Shipping Mode vs Count

sns.catplot('Ship Mode',data=df,hue='Segment',kind="count",palette='magma_r',aspect=1.5,height=7)
plt.show()

# %% [markdown]
# ### Most Profitable Categories

# %%
dfprofit = df.groupby('Category')['Profit'].sum().reset_index()
print(dfprofit)
plt.figure(figsize=(5,5))
labels=dfprofit['Category'].unique()
plt.pie(dfprofit['Profit'],autopct='%1.1f%%',labels=labels,explode=(0.02,0.02,0.02))

plt.title('Distribution of profits categorywise',size=20)
plt.show()
# Out:
#           Category       Profit
# 0        Furniture   18421.8137
# 1  Office Supplies  122364.6608
# 2       Technology  145454.9481

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#Most Profitable Categories

dfprofit = df.groupby('Sub-Category')['Profit'].sum().reset_index()
print(dfprofit)
plt.figure(figsize=(5,5))
labels=dfprofit['Sub-Category'].unique()
plt.pie(dfprofit['Profit'],autopct='%1.1f%%',labels=labels,explode=(0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.2,0.2))

plt.title('Distribution of profits Sub-categorywise',size=50)


plt.show()
# Out:
#    Sub-Category      Profit
# 0   Accessories  41936.6357
# 1    Appliances  18138.0054
# 2           Art   6524.6118
# 3       Binders  30228.0003
# 4     Bookcases  -3472.5560
# 5        Chairs  26567.1278
# 6       Copiers  55617.8249
# 7     Envelopes   6964.1767
# 8     Fasteners    949.5182
# 9   Furnishings  13052.7230
# 10       Labels   5526.3820
# 11     Machines   3384.7569
# 12        Paper  33944.2395
# 13       Phones  44515.7306
# 14      Storage  21278.8264
# 15     Supplies  -1189.0995
# 16       Tables -17725.4811

# %%
# copies gives height profits

# %%
# Top 10 Profitable cities

dftop10_cities = df.groupby('City')['Profit'].sum().reset_index().sort_values(by='Profit',ascending=False)
dftop10_cities = dftop10_cities.head(10)
dftop10_cities
# Out:
#               City      Profit
# 329  New York City  62036.9837
# 266    Los Angeles  30440.7579
# 452        Seattle  29156.0967
# 438  San Francisco  17507.3854
# 123        Detroit  13181.7908
# 233      Lafayette  10018.3876
# 215        Jackson   7581.6828
# 21         Atlanta   6993.6629
# 300    Minneapolis   6824.5846
# 437      San Diego   6377.1960

# %%
#Visualizing the Top 10 Profitable Products

sns.catplot('City','Profit',data=dftop10_cities,kind='bar',aspect=1.5,height=9,palette='cubehelix_r')
plt.title('Top 10 profitable Cities',size=20) #'ch:2.5,-.2,dark=.3'
plt.xticks(size=15)
plt.yticks(size=15)
plt.ylabel('Comulative profit',size=18)
plt.xlabel('Cities',size=18)
plt.show()


# Comulative Profit : CP is the total net profits from the specified segments added together over a specific time Frame.

# %%
# Top Profitable States

dftop10_States = df.groupby('State')['Profit'].sum().reset_index().sort_values(by='Profit',ascending=False)
dftop10_States = dftop10_States.head(10)
dftop10_States
# Out:
#          State      Profit
# 3   California  76381.3871
# 30    New York  74038.5486
# 45  Washington  33402.6517
# 20    Michigan  24463.1876
# 44    Virginia  18597.9504
# 12     Indiana  18382.9363
# 9      Georgia  16250.0433
# 15    Kentucky  11199.6966
# 21   Minnesota  10823.1874
# 6     Delaware   9977.3748

# %%
#Visualizing the Top 10 Profitable Products

sns.catplot('State','Profit',data=dftop10_States,kind='bar',aspect=1.5,height=9,palette= 'gist_earth')
plt.title('Top 10 profitable States',size=20) #'ch:2.5,-.2,dark=.3'
plt.xticks(size=15)
plt.yticks(size=15)
plt.ylabel('Cumulative profit',size=18)
plt.xlabel('States',size=18)

plt.show()

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df = data.copy()

# %%
dftop_Region = df.groupby('Region')['Profit'].sum().reset_index().sort_values(by='Profit',ascending=False)
dftop_Region = dftop_Region.head(10)
dftop_Region
# Out:
#     Region       Profit
# 3     West  108418.4489
# 1     East   91522.7800
# 2    South   46749.4303
# 0  Central   39706.3625

# %%
#Visualizing the Top Profitable Region

sns.catplot('Region','Profit',data=dftop_Region,kind='bar',aspect=1.5,height=9,palette= 'cool')
plt.title('Top profitable Regions',size=20) #'ch:2.5,-.2,dark=.3'
plt.xticks(size=15)
plt.yticks(size=15)
plt.ylabel('Cumulative profit',size=18)
plt.xlabel('Region',size=18)

plt.show()

# %% [markdown]
# # <h1><font color="dark"> What is the total profit and Sales of the company ?   </font><h1>

# %%
sales = df['Sales'].sum()
profit = df['Profit'].sum()
print("Total sales  : {}  USD".format(sales))
print("Total profit : {} USD".format(profit))
# Out:
# Total sales  : 2297200.8603  USD
# Total profit : 286397.0217 USD

# %%
#lets try to understand the Regression Plot 
plt.figure(figsize=(12,8))
sns.regplot(df['Sales'],df['Profit'])

# %% [raw]
# ## from Sales and Profit we can clearly obsurved the positive in between , as the Sales increases the profit also increses
# accordingly

# %% [raw]
# Summary:
#     1. Number of Columns in the Dataset : 13
#     2. Number of Rows in the Dataset : 9994
#     3. Number of Numerical Features : 5
#     4. Number of Categorical Features : 8
#     5. Data does not have any none values,so we need not to perform data filling .
#     6. Some of the features has outlires.
#     7. The City that gives height profit :  New York City
#     8. The City that gives lowest profit :  Philadelphia
#     9. The State that gives height profits : California
#     10. The State that gives lowest profits : Texas
#     11. The Region that gives height profits : WESt
#     12. The Region that gives comparatebly low profits : Central
#
#
#
#     Conclusion:
#
#         we see that some of the Cityies perform very bad in terms of providing profite we must look on that so that we
#         can made more profit on that as same goes on the state wise, in Region wise we can see tht West and East gives
#         preety good profits and we need to improve our profits from Souts and Central Regions as it gives comparetably
#         low profits.
